# %%
import pandas as pd
d=pd.read_excel("akilan's_company.xlsx")
print(d)
# Out:
#     S.no:  Name of the employee Gender   Experience(years)  Join date  \
# 0       1               Abinith      M                   2     2023.0
# 1       2                Akilan      M                  20     2005.0
# 2       3                   Anu      F                   6     2019.0
# 3       4               Aravind      M                   5     2020.0
# 4       5                 Arjun      M                   8     2017.0
# 5       6                  Arya      M                  13       20.0
# 6       7                Ashwin      M                  19        NaN
# 7       8                  Babu      M                  15        NaN
# 8       9    Jency gnayanaolivu      F                  50        NaN
# 9      10           Balamurugan      M                   4        NaN
# 10     11                Bhavya      F                   8        NaN
# 11     12                Bhavan      M                   9        NaN
# ...

# %%
import pandas as pd
d=pd.read_excel("akilan's_company.xlsx")
print(d)
df=pd.DataFrame(d)
print("columns",df.columns)
print(df.shape)
# Out:
#     S.no:  Name of the employee Gender   Experience(years)  Join date  \
# 0       1               Abinith      M                   2       2023
# 1       2                Akilan      M                  20       2005
# 2       3                   Anu      F                   6       2019
# 3       4               Aravind      M                   5       2020
# 4       5                 Arjun      M                   8       2017
# 5       6                  Arya      M                  13       2012
# 6       7                Ashwin      M                  19       2006
# 7       8                  Babu      M                  15       2010
# 8       9    Jency gnayanaolivu      F                  50       1975
# 9      10           Balamurugan      M                   4       2021
# 10     11                Bhavya      F                   8       2017
# 11     12                Bhavan      M                   9       2016
# ...

# %%
import pandas as pd
d=pd.read_excel("akilan's_company.xlsx")
print(d)
print("Gender",df['Gender'])
# Out:
#     S.no:  Name of the employee Gender   Experience(years)  Join date  \
# 0       1               Abinith      M                   2       2023
# 1       2                Akilan      M                  20       2005
# 2       3                   Anu      F                   6       2019
# 3       4               Aravind      M                   5       2020
# 4       5                 Arjun      M                   8       2017
# 5       6                  Arya      M                  13       2012
# 6       7                Ashwin      M                  19       2006
# 7       8                  Babu      M                  15       2010
# 8       9    Jency gnayanaolivu      F                  50       1975
# 9      10           Balamurugan      M                   4       2021
# 10     11                Bhavya      F                   8       2017
# 11     12                Bhavan      M                   9       2016
# ...

# %%
import pandas as pd
d=pd.read_excel("akilan's_company.xlsx")
print(d)
print(df[1:5])
# Out:
#     S.no:  Name of the employee Gender   Experience(years)  Join date  \
# 0       1               Abinith      M                   2       2023
# 1       2                Akilan      M                  20       2005
# 2       3                   Anu      F                   6       2019
# 3       4               Aravind      M                   5       2020
# 4       5                 Arjun      M                   8       2017
# 5       6                  Arya      M                  13       2012
# 6       7                Ashwin      M                  19       2006
# 7       8                  Babu      M                  15       2010
# 8       9    Jency gnayanaolivu      F                  50       1975
# 9      10           Balamurugan      M                   4       2021
# 10     11                Bhavya      F                   8       2017
# 11     12                Bhavan      M                   9       2016
# ...

# %%
import pandas as pd
d=pd.read_excel("akilan's_company.xlsx")
print("particular person details",df.loc[9])
# Out:
# particular person details S.no:                             10
#  Name of the employee    Balamurugan
# Gender                             M
#  Experience(years)                 4
# Join date                       2021
# Last login Time             16:00:00
# Senior manager                     F
# Salary                           NaN
# Bonus                            NaN
# Name: 9, dtype: object

# %%
import pandas as pd
d=pd.read_excel("akilan's_company.xlsx")
print(d.loc[d['Gender']=='F'])
# Out:
#     S.no:  Name of the employee Gender   Experience(years)  Join date  \
# 2       3                   Anu      F                   6       2019
# 8       9    Jency gnayanaolivu      F                  50       1975
# 10     11                Bhavya      F                   8       2017
# 13     14           Mirnalnigga      F                  60       1965
# 16     17                 Kavya      F                  50       1975
# 23     24               Mithali      F                   2       2023
#
#         Last login Time Senior manager  Salary  Bonus
# 2              12:00:00              F     NaN    NaN
# 8              15:00:00              T     NaN    NaN
# 10             17:00:00              F     NaN    NaN
# 13             20:00:00              T     NaN    NaN
# 16             23:00:00              F     NaN    NaN
# 23  1900-01-01 06:00:00              F     NaN    NaN

# %%
import pandas as pd
d=pd.read_excel("akilan's_company.xlsx")
df=d['']/999
print(df)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# Name: Salary, dtype: float64
